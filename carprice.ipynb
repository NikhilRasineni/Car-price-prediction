# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from sklearn import metrics
sns.set_style('darkgrid')

# %%
df=pd.read_csv('carprices.csv')

# %%
df.head().T
# Out:
#                                    0  ...           4
# car_ID                             1  ...           5
# symboling                          3  ...           2
# CarName           alfa-romero giulia  ...  audi 100ls
# fueltype                         gas  ...         gas
# aspiration                       std  ...         std
# doornumber                       two  ...        four
# carbody                  convertible  ...       sedan
# drivewheel                       rwd  ...         4wd
# enginelocation                 front  ...       front
# wheelbase                       88.6  ...        99.4
# carlength                      168.8  ...       176.6
# carwidth                        64.1  ...        66.4
# carheight                       48.8  ...        54.3
# curbweight                      2548  ...        2824
# enginetype                      dohc  ...         ohc
# cylindernumber                  four  ...        five
# enginesize                       130  ...         136
# fuelsystem                      mpfi  ...        mpfi
# boreratio                       3.47  ...        3.19
# stroke                          2.68  ...         3.4
# compressionratio                 9.0  ...         8.0
# horsepower                       111  ...         115
# peakrpm                         5000  ...        5500
# citympg                           21  ...          18
# highwaympg                        27  ...          22
# price                        13495.0  ...     17450.0
#
# [26 rows x 5 columns]

# %%
df.shape
# Out:
# (205, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %%
df.drop('car_ID',axis=1,inplace=True)

# %%
df['CarName'].value_counts()
# Out:
# toyota corona           6
# toyota corolla          6
# peugeot 504             6
# subaru dl               4
# mitsubishi mirage g4    3
#                        ..
# mazda glc 4             1
# mazda rx2 coupe         1
# maxda glc deluxe        1
# maxda rx3               1
# volvo 246               1
# Name: CarName, Length: 147, dtype: int64

# %%
df['CarName'].str.split(' ').str.get(0).nunique()
# Out:
# 28

# %%
df['company']=df['CarName'].str.split(' ').str.get(0)

# %%
df['company'].value_counts()
# Out:
# toyota         31
# nissan         17
# mazda          15
# honda          13
# mitsubishi     13
# subaru         12
# peugeot        11
# volvo          11
# volkswagen      9
# dodge           9
# buick           8
# bmw             8
# audi            7
# plymouth        7
# saab            6
# isuzu           4
# porsche         4
# alfa-romero     3
# chevrolet       3
# jaguar          3
# vw              2
# maxda           2
# renault         2
# toyouta         1
# vokswagen       1
# Nissan          1
# mercury         1
# porcshce        1
# Name: company, dtype: int64

# %% [markdown]
# spelling mistakes of porschr,mazda,volkswagon

# %%
df.loc[df['company']=='vw','company']='volkswagen'
df.loc[df['company']=='porcshce','company']='porsche'
df.loc[df['company']=='nissan','company']='Nissan'
df.loc[df['company']=='maxda','company']='mazda'
df.loc[df['company']=='toyouta','company']='toyota'
df.loc[df['company']=='vokswagen','company']='volkswagen'

# %%
df['company'].value_counts()
# Out:
# toyota         32
# Nissan         18
# mazda          17
# mitsubishi     13
# honda          13
# volkswagen     12
# subaru         12
# peugeot        11
# volvo          11
# dodge           9
# buick           8
# bmw             8
# audi            7
# plymouth        7
# saab            6
# porsche         5
# isuzu           4
# jaguar          3
# chevrolet       3
# alfa-romero     3
# renault         2
# mercury         1
# Name: company, dtype: int64

# %%
df.drop('CarName',axis=1,inplace=True)

# %%
df['company'].value_counts(normalize=True)*100
# Out:
# toyota         15.609756
# Nissan          8.780488
# mazda           8.292683
# mitsubishi      6.341463
# honda           6.341463
# volkswagen      5.853659
# subaru          5.853659
# peugeot         5.365854
# volvo           5.365854
# dodge           4.390244
# buick           3.902439
# bmw             3.902439
# audi            3.414634
# plymouth        3.414634
# saab            2.926829
# porsche         2.439024
# isuzu           1.951220
# jaguar          1.463415
# chevrolet       1.463415
# alfa-romero     1.463415
# renault         0.975610
# mercury         0.487805
# Name: company, dtype: float64

# %%
def group(x):
  if 'renault' in x:
    return 'other'
  elif 'mercury'in x:
    return 'other'
  else:
    return x

# %%
df['company']=df['company'].apply(lambda x:group(x))

# %%
df['company'].value_counts(normalize=True)*100
# Out:
# toyota         15.609756
# Nissan          8.780488
# mazda           8.292683
# honda           6.341463
# mitsubishi      6.341463
# subaru          5.853659
# volkswagen      5.853659
# peugeot         5.365854
# volvo           5.365854
# dodge           4.390244
# buick           3.902439
# bmw             3.902439
# audi            3.414634
# plymouth        3.414634
# saab            2.926829
# porsche         2.439024
# isuzu           1.951220
# alfa-romero     1.463415
# jaguar          1.463415
# chevrolet       1.463415
# other           1.463415
# Name: company, dtype: float64

# %%
df.dtypes
# Out:
# symboling             int64
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# company              object
# dtype: object

# %%
cat_col=[df.dtypes.index[i] for i in range(len(df.dtypes)) if df.dtypes[i]=='object']

# %%
cat_col
# Out:
# ['fueltype',
#  'aspiration',
#  'doornumber',
#  'carbody',
#  'drivewheel',
#  'enginelocation',
#  'enginetype',
#  'cylindernumber',
#  'fuelsystem',
#  'company']

# %%
num_col=[i for i in df.columns if i not in cat_col]

# %%
num_col
# Out:
# ['symboling',
#  'wheelbase',
#  'carlength',
#  'carwidth',
#  'carheight',
#  'curbweight',
#  'enginesize',
#  'boreratio',
#  'stroke',
#  'compressionratio',
#  'horsepower',
#  'peakrpm',
#  'citympg',
#  'highwaympg',
#  'price']

# %% [markdown]
# #EDA

# %% [markdown]
# ##UNIVARIATE ANALYSIS

# %%
for i in cat_col:
  if i!='company':
    print('\n',df[i].value_counts(normalize=True)*100)
  else:
    pass
# Out:
#  gas       90.243902
# diesel     9.756098
# Name: fueltype, dtype: float64
#
#  std      81.95122
# turbo    18.04878
# Name: aspiration, dtype: float64
#
#  four    56.097561
# two     43.902439
# Name: doornumber, dtype: float64
#
#  sedan          46.829268
# hatchback      34.146341
# wagon          12.195122
# hardtop         3.902439
# convertible     2.926829
# Name: carbody, dtype: float64
#
#  fwd    58.536585
# rwd    37.073171
# 4wd     4.390244
# Name: drivewheel, dtype: float64
#
#  front    98.536585
# rear      1.463415
# Name: enginelocation, dtype: float64
#
#  ohc      72.195122
# ohcf      7.317073
# ohcv      6.341463
# dohc      5.853659
# l         5.853659
# rotor     1.951220
# dohcv     0.487805
# Name: enginetype, dtype: float64
#
#  four      77.560976
# six       11.707317
# five       5.365854
# eight      2.439024
# two        1.951220
# three      0.487805
# twelve     0.487805
# Name: cylindernumber, dtype: float64
#
#  mpfi    45.853659
# 2bbl    32.195122
# idi      9.756098
# 1bbl     5.365854
# spdi     4.390244
# 4bbl     1.463415
# mfi      0.487805
# spfi     0.487805
# Name: fuelsystem, dtype: float64

# %%
 for i in cat_col:
  if i!='company':
    fig,ax=plt.subplots()
    plt.title(i)
    sns.barplot(x=df[i].value_counts().index,y=(df[i].value_counts(normalize=True)*100).values)

# %%
for col in num_col:
  plt.subplot(1,2,1)
  sns.histplot(df[col],kde=True)
  plt.subplot(1,2,2)
  sns.boxplot(df[col])
  plt.tight_layout()
  plt.show()

# %% [markdown]
# Checking for outliers in compression ratio

# %%
df[df['compressionratio']>15]
# Out:
#      symboling fueltype aspiration  ... highwaympg    price     company
# 63           0   diesel        std  ...         42  10795.0       mazda
# 66           0   diesel        std  ...         39  18344.0       mazda
# 67          -1   diesel      turbo  ...         25  25552.0       buick
# 68          -1   diesel      turbo  ...         25  28248.0       buick
# 69           0   diesel      turbo  ...         25  28176.0       buick
# 70          -1   diesel      turbo  ...         25  31600.0       buick
# 90           1   diesel        std  ...         50   7099.0      Nissan
# 108          0   diesel      turbo  ...         33  13200.0     peugeot
# 110          0   diesel      turbo  ...         25  13860.0     peugeot
# 112          0   diesel      turbo  ...         33  16900.0     peugeot
# 114          0   diesel      turbo  ...         25  17075.0     peugeot
# 116          0   diesel      turbo  ...         33  17950.0     peugeot
# 158          0   diesel        std  ...         36   7898.0      toyota
# 159          0   diesel        std  ...         47   7788.0      toyota
# 174         -1   diesel      turbo  ...         33  10698.0      toyota
# 182          2   diesel        std  ...         46   7775.0  volkswagen
# 184          2   diesel        std  ...         46   7995.0  volkswagen
# 187          2   diesel      turbo  ...         42   9495.0  volkswagen
# 192          0   diesel      turbo  ...         38  13845.0  volkswagen
# 203         -1   diesel      turbo  ...         27  22470.0       volvo
#
# [20 rows x 25 columns]

# %%
sns.boxplot(x='fueltype',y='compressionratio',data=df);

# %% [markdown]
# As the engines with compression ratio greater than 20  are diesel engines,I am not dropping them

# %% [markdown]
# Checking for outliers in enginesize feature

# %%
df['enginesize'].quantile([0.95,0.96,0.97,0.98,0.99,1])
# Out:
# 0.95    201.20
# 0.96    209.00
# 0.97    231.00
# 0.98    256.08
# 0.99    302.16
# 1.00    326.00
# Name: enginesize, dtype: float64

# %%
df[df['enginesize']>250]
# Out:
#     symboling fueltype aspiration  ... highwaympg    price company
# 47          0      gas        std  ...         19  32250.0  jaguar
# 48          0      gas        std  ...         19  35550.0  jaguar
# 49          0      gas        std  ...         17  36000.0  jaguar
# 73          0      gas        std  ...         16  40960.0   buick
# 74          1      gas        std  ...         16  45400.0   buick
#
# [5 rows x 25 columns]

# %% [markdown]
# Seems like valid datapoints so no need to remove them

# %% [markdown]
# checking for outliers in price feature

# %%
df['price'].quantile([0.95,0.96,0.97,0.98,0.99])
# Out:
# 0.95    32472.40
# 0.96    34159.04
# 0.97    35490.72
# 0.98    36809.60
# 0.99    40802.72
# Name: price, dtype: float64

# %%
df[df['price']>30000]
# Out:
#      symboling fueltype aspiration  ... highwaympg    price  company
# 15           0      gas        std  ...         22  30760.0      bmw
# 16           0      gas        std  ...         22  41315.0      bmw
# 17           0      gas        std  ...         20  36880.0      bmw
# 47           0      gas        std  ...         19  32250.0   jaguar
# 48           0      gas        std  ...         19  35550.0   jaguar
# 49           0      gas        std  ...         17  36000.0   jaguar
# 70          -1   diesel      turbo  ...         25  31600.0    buick
# 71          -1      gas        std  ...         18  34184.0    buick
# 72           3      gas        std  ...         18  35056.0    buick
# 73           0      gas        std  ...         16  40960.0    buick
# 74           1      gas        std  ...         16  45400.0    buick
# 126          3      gas        std  ...         25  32528.0  porsche
# 127          3      gas        std  ...         25  34028.0  porsche
# 128          3      gas        std  ...         25  37028.0  porsche
# 129          1      gas        std  ...         28  31400.5  porsche
#
# [15 rows x 25 columns]

# %% [markdown]
# seems like outliers but are actually not

# %% [markdown]
# ##BIVARIATE ANALYSIS

# %% [markdown]
# exploring price vs company

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='company',y='price',data=df);
plt.xticks(rotation='vertical');

# %% [markdown]
# exploring engine size vs price

# %%
sns.jointplot(x='enginesize',y='price',data=df,kind='reg');

# %%
print('engine size and price are highly corelated with a coefficent of',np.round(df['enginesize'].corr(df['price']),2))
# Out:
# engine size and price are highly corelated with a coefficent of 0.87

# %%
sns.jointplot(x='citympg',y='price',data=df);

# %%
sns.boxplot(x='enginetype',y='price',data=df);

# %%
sns.boxplot(x='cylindernumber',y='price',data=df);

# %%
sns.boxplot(x='fuelsystem',y='price',data=df);

# %%
sns.boxplot(x='aspiration',y='price',data=df);

# %%
sns.scatterplot(x='horsepower',y='price',data=df);

# %%
sns.boxplot(x='carbody',y='price',data=df);

# %%
sns.boxplot(x='doornumber',y='price',data=df);

# %%
df['drivewheel'].value_counts()
# Out:
# fwd    120
# rwd     76
# 4wd      9
# Name: drivewheel, dtype: int64

# %%
sns.boxplot(x='drivewheel',y='price',data=df);

# %% [markdown]
# ## MULTIVARIATE ANALYSIS

# %%
sns.scatterplot(x='horsepower',y='price',hue='fueltype',data=df);

# %%
sns.scatterplot(x='peakrpm',y='price',hue='cylindernumber',data=df);

# %%
sns.scatterplot(x='enginesize',y='price',hue='cylindernumber',data=df);

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),cmap='rocket',annot=True);

# %% [markdown]
# Citympg is highly corelated with highwaympg..so we can drop one

# %%
df.drop('highwaympg',axis=1,inplace=True)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),cmap='rocket',annot=True);

# %%
df.drop('wheelbase',axis=1,inplace=True)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,cmap='rocket');

# %%
corr=df.corr()['price'].sort_values(ascending=False)[1:]

# %%
corr
# Out:
# enginesize          0.874145
# curbweight          0.835305
# horsepower          0.808139
# carwidth            0.759325
# carlength           0.682920
# boreratio           0.553173
# carheight           0.119336
# stroke              0.079443
# compressionratio    0.067984
# symboling          -0.079978
# peakrpm            -0.085267
# citympg            -0.685751
# Name: price, dtype: float64

# %%
plt.figure(figsize=(15,8))
sns.lineplot(x=corr.index,y=corr.values,color='black');
plt.xticks(rotation='vertical');

# %%
cat_col
# Out:
# ['fueltype',
#  'aspiration',
#  'doornumber',
#  'carbody',
#  'drivewheel',
#  'enginelocation',
#  'enginetype',
#  'cylindernumber',
#  'fuelsystem',
#  'company']

# %%
catdf=df[cat_col]

# %%
dummies=pd.get_dummies(catdf,drop_first=True)

# %%
dummies.shape
# Out:
# (205, 49)

# %%
df1=df.drop(list(catdf.columns),axis=1)

# %%
df2=pd.concat([df1,dummies],axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
X=df2.drop('price',axis=1)
y=df2['price']

# %%
X_train, X_test, y_train, y_test =train_test_split(X,y,test_size=0.25,random_state=1)

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()

# %%
from sklearn import metrics
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
param={
    'criterion':['squared_error', 'absolute_error', 'poisson'],
    'max_depth':range(2,5),
    'max_features':['auto', 'sqrt', 'log2'],

}

# %%
from sklearn.model_selection import GridSearchCV
search=GridSearchCV(rf,param,n_jobs=-1,cv=5)
search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'poisson'],
#                          'max_depth': range(2, 5),
#                          'max_features': ['auto', 'sqrt', 'log2']})

# %%
search.best_params_
# Out:
# {'criterion': 'squared_error', 'max_depth': 4, 'max_features': 'auto'}

# %%
y_pred_gridtrain=search.predict(X_train)

# %%
y_pred_gridtest=search.predict(X_test)

# %%
n,p=X_train.shape[0],X_train.shape[1]

# %%
r2tr=metrics.r2_score(y_train,y_pred_gridtrain)
print(f'R2Score on Training data is {r2tr}')
num=(1-r2tr)*(n-1)
den=n-p-1
ar2tr=1-(num/den)
print(f'Adjusted R2 score for training data is {ar2tr}')
# Out:
# R2Score on Training data is 0.9586194850152432
# Adjusted R2 score for training data is 0.9308808980474392

# %%
r2te=metrics.r2_score(y_test,y_pred_gridtest)
print(f'R2score on Testing data is {r2te}')
num=(1-r2te)*(n-1)
den=n-p-1
ar2te=1-(num/den)

print(f'Adjusted R2 score for testing data is {ar2te}')
# Out:
# R2score on Testing data is 0.924500263868619
# Adjusted R2 score for testing data is 0.8738905506376934

# %%
s1=pd.Series(rf.feature_importances_)

# %%
s2=pd.Series(X_train.columns.to_list())

# %%
fi=pd.concat([s1,s2],axis=1)

# %%
fi
# Out:
#            0                   1
# 0   0.001485           symboling
# 1   0.008193           carlength
# 2   0.016035            carwidth
# 3   0.003783           carheight
# 4   0.232722          curbweight
# ..       ...                 ...
# 56  0.000032        company_saab
# 57  0.000013      company_subaru
# 58  0.000569      company_toyota
# 59  0.000197  company_volkswagen
# 60  0.000232       company_volvo
#
# [61 rows x 2 columns]
